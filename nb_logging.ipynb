# %%
# Out:
# StatementMeta(, 873a1a30-7af4-4564-8902-a52de072741e, 3, Finished, Available, Finished)
# StatementMeta(, 873a1a30-7af4-4564-8902-a52de072741e, 4, Finished, Available, Finished)
# 2026-01-01 18:32:23 - nb_logging - INFO - Logging notebook initialized successfully.

# %%
# nb_logging
import logging
import sys

# %%
def get_logger(name):
    """
    Creates a standardized logger for Fabric Notebooks.
    """
    logger = logging.getLogger(name)
    
    # Avoid duplicate logs if the logger is already initialized
    if not logger.handlers:
        logger.setLevel(logging.INFO)
        handler = logging.StreamHandler(sys.stderr)
        formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s', datefmt='%Y-%m-%d %H:%M:%S')
        handler.setFormatter(formatter)
        logger.addHandler(handler)
        
    return logger

# Test the logger
logger = get_logger("nb_logging")
logger.info("Logging notebook initialized successfully.")
